# %%
from sklearn.linear_model import LogisticRegression, ElasticNetCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.feature_selection import RFE, SelectKBest, mutual_info_classif
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import f1_score
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours, NearMiss
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, ADASYN, RandomOverSampler
from imblearn.combine import SMOTETomek, SMOTEENN
from scipy.stats import chi2_contingency
import warnings
import os
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
train_path = os.path.join("..", "data", "input", "train_treated.csv")
val_path = os.path.join("..", "data", "input", "val_treated.csv")
test_path = os.path.join("..", "data", "input", "test_treated.csv")
y_path = os.path.join("..", "data", "input", "target.csv")
# this should be the one we use
# test_path = os.path.join("..", "data", "input", "y_bin.csv")

X_train = pd.read_csv(train_path, index_col=0)
X_val = pd.read_csv(val_path, index_col=0)
test = pd.read_csv(test_path, index_col=0)
y = pd.read_csv(y_path, index_col=0)

# %%
X = pd.concat([X_train, X_val], axis=0)
X.head()
# Out:
#                          race  gender       age payer_code  \
# encounter_id
# 672135              Caucasian    Male  [90-100)         MC
# 794587        AfricanAmerican  Female   [70-80)    Unknown
# 694232              Caucasian    Male   [80-90)         MC
# 305869        AfricanAmerican    Male   [70-80)    Unknown
# 181753              Caucasian  Female   [70-80)         MC
#
#               outpatient_visits_in_previous_year  \
# encounter_id
# 672135                                         0
# 794587                                         0
# 694232                                         0
# 305869                                         0
# 181753                                         0
#
#               emergency_visits_in_previous_year  \
# encounter_id
# 672135                                        0
# 794587                                        0
# 694232                                        0
# 305869                                        0
# 181753                                        0
#
#               inpatient_visits_in_previous_year admission_type  \
# encounter_id
# 672135                                        0      Emergency
# 794587                                        0      Emergency
# 694232                                        0      Emergency
# 305869                                        3      Emergency
# 181753                                        0      Emergency
#
#               average_pulse_bpm  \
# encounter_id
# 672135                       93
# 794587                       74
# 694232                       83
# 305869                       67
# 181753                      126
#
#                                           discharge_disposition  ...  \
# encounter_id                                                     ...
# 672135                                                  Expired  ...
# 794587                                       Discharged to home  ...
# 694232                                       Discharged to home  ...
# 305869                                       Discharged to home  ...
# 181753        Discharged/transferred to another rehab fac in...  ...
#
#              med_glimepiride-pioglitazone  med_nateglinide  med_glipizide  \
# encounter_id
# 672135                                  0                0              0
# 794587                                  0                0              0
# 694232                                  0                0              0
# 305869                                  0                0              0
# 181753                                  0                0              1
#
#               med_insulin  med_metformin-pioglitazone  \
# encounter_id
# 672135                  1                           0
# 794587                  1                           0
# 694232                  0                           0
# 305869                  0                           0
# 181753                  0                           0
#
#               med_metformin-rosiglitazone med_chlorpropamide med_miglitol  \
# encounter_id
# 672135                                  0                  0            0
# 794587                                  0                  0            0
# 694232                                  0                  0            0
# 305869                                  0                  0            0
# 181753                                  0                  0            0
#
#              med_repaglinide med_tolbutamide
# encounter_id
# 672135                     0               0
# 794587                     0               0
# 694232                     0               0
# 305869                     0               0
# 181753                     0               0
#
# [5 rows x 67 columns]

# %%
y = y.reindex(X.index)
y.head()
# Out:
#              readmitted_binary
# encounter_id
# 672135                      No
# 794587                      No
# 694232                      No
# 305869                      No
# 181753                      No

# %% [markdown]
# ## balancing the dataset

# %% [markdown]
# after some research found there are three main categories to balance data, __undersampling__, __oversampling__, and a __combination__ of both.
#
# will test all of them to decide which will be the best method to use

# %%
def evaluate(balancer):
    
    skf = StratifiedKFold(n_splits=5, shuffle=True)
    model = GradientBoostingClassifier(
        verbose=1,
        random_state = 42
    )
    
    score_train = []
    score_test = []
    timer = []
    f1_s = []
    
    for train_index, test_index in skf.split(X, y, ):
        # get the indexes of the observations assigned for each partition
        X_train, X_val = X.iloc[train_index], X.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]

        X_res, y_res = balancer.fit_resample(X_train, y_train)
        
        # start counting time
        begin = time.perf_counter()
        # fit the model to the data
        model.fit(X_res, y_res)
        # finish counting time
        end = time.perf_counter()
        # check the mean accuracy for the train
        value_train = model.score(X_res, y_res)
        # check the mean accuracy for the test
        value_test = model.score(X_val, y_val)
        # check the f1 score
        y_pred = model.predict(X_val)
        value_f1 = f1_score(y_val, y_pred, pos_label='Yes')
        # append the accuracies, the time and the number of iterations in the corresponding list
        score_train.append(value_train)
        score_test.append(value_test)
        timer.append(end-begin)
        f1_s.append(value_f1)
    # calculate the average and the std for each measure (accuracy, time and number of iterations)
    avg_time = round(np.mean(timer), 3)
    avg_train = round(np.mean(score_train), 3)
    avg_test = round(np.mean(score_test), 3)
    std_time = round(np.std(timer), 2)
    std_train = round(np.std(score_train), 2)
    std_test = round(np.std(score_test), 2)
    avg_f1 = round(np.mean(f1_s), 6)
    std_f1 = round(np.std(f1_s), 6)

    return str(avg_time) + '+/-' + str(std_time), str(avg_train) + '+/-' + str(std_train), \
        str(avg_test) + '+/-' + str(std_test), str(avg_f1) + '+/-' + str(std_f1)

def show_results(df, *args):
    for i, arg in enumerate(args):
        time, avg_train, avg_test, f1 = evaluate(arg)
        df.iloc[i] = time, avg_train, avg_test, f1
    return df

# %%
results_empty = pd.DataFrame(columns=['Time', 'Train', 'Test', 'f1'], index=[
                             'Tomek', 'ENN', 'NearMiss'])

results_under = show_results(results_empty,
                       TomekLinks(n_jobs=4),
                       EditedNearestNeighbours(n_neighbors=5, kind_sel='all', n_jobs=4),
                       NearMiss(n_jobs=4))

results_under
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.7076           34.58s
#          2           0.7015           34.37s
#          3           0.6969           34.16s
#          4           0.6931           33.77s
#          5           0.6901           33.21s
#          6           0.6877           33.05s
#          7           0.6857           32.74s
#          8           0.6840           32.36s
#          9           0.6825           32.36s
#         10           0.6812           32.09s
#         20           0.6733           28.23s
#         30           0.6690           24.58s
#         40           0.6664           20.90s
#         50           0.6642           17.47s
#         60           0.6622           13.94s
#         70           0.6606           10.48s
#         80           0.6594            6.98s
#         90           0.6583            3.48s
#        100           0.6571            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Fabian\Documents\MSc\1st Semester\ML\final-project\hospital-readmission-v2\notebooks\feature-selection.ipynb Cell 8 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> results_empty = pd.DataFrame(columns=['Time', 'Train', 'Test', 'f1'], index=[
#       <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>                              'Tomek', 'ENN', 'NearMiss'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> results_under = show_results(results_empty,
#       <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>                        TomekLinks(n_jobs=4),
#       <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>                        EditedNearestNeighbours(n_neighbors=5, kind_sel='all', n_jobs=4),
#       <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>                        NearMiss(n_jobs=4))
#       <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> results_under
#
# c:\Users\Fabian\Documents\MSc\1st Semester\ML\final-project\hospital-readmission-v2\notebooks\feature-selection.ipynb Cell 8 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=51'>52</a> def show_results(df, *args):
#      <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=52'>53</a>     for i, arg in enumerate(args):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=53'>54</a>         time, avg_train, avg_test, f1 = evaluate(arg)
#      <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=54'>55</a>         df.iloc[i] = time, avg_train, avg_test, f1
#      <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=55'>56</a>     return df
#
# c:\Users\Fabian\Documents\MSc\1st Semester\ML\final-project\hospital-readmission-v2\notebooks\feature-selection.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=21'>22</a> begin = time.perf_counter()
#      <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=22'>23</a> # fit the model to the data
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a> model.fit(X_res, y_res)
#      <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=24'>25</a> # finish counting time
#      <a href='vscode-notebook-cell:/c%3A/Users/Fabian/Documents/MSc/1st%20Semester/ML/final-project/hospital-readmission-v2/notebooks/feature-selection.ipynb#X10sZmlsZQ%3D%3D?line=25'>26</a> end = time.perf_counter()
#
# File c:\Users\Fabian\anaconda3\envs\group-23-env\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Fabian\anaconda3\envs\group-23-env\Lib\site-packages\sklearn\ensemble\_gb.py:525, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     522     self._resize_state()
#     524 # fit the boosting stages
# --> 525 n_stages = self._fit_stages(
#     526     X,
#     527     y,
#     528     raw_predictions,
#     529     sample_weight,
#     530     self._rng,
#     531     X_val,
#     532     y_val,
#     533     sample_weight_val,
#     534     begin_at_stage,
#     535     monitor,
#     536 )
#     538 # change shape of arrays after fit (early-stopping or additional ests)
#     539 if n_stages != self.estimators_.shape[0]:
#
# File c:\Users\Fabian\anaconda3\envs\group-23-env\Lib\site-packages\sklearn\ensemble\_gb.py:603, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     596         initial_loss = loss_(
#     597             y[~sample_mask],
#     598             raw_predictions[~sample_mask],
#     599             sample_weight[~sample_mask],
#     600         )
#     602 # fit next stage of trees
# --> 603 raw_predictions = self._fit_stage(
#     604     i,
#     605     X,
#     606     y,
#     607     raw_predictions,
#     608     sample_weight,
#     609     sample_mask,
#     610     random_state,
#     611     X_csc,
#     612     X_csr,
#     613 )
#     615 # track loss
#     616 if do_oob:
#
# File c:\Users\Fabian\anaconda3\envs\group-23-env\Lib\site-packages\sklearn\ensemble\_gb.py:245, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     242     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     244 X = X_csr if X_csr is not None else X
# --> 245 tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     247 # update tree leaves
#     248 loss.update_terminal_regions(
#     249     tree.tree_,
#     250     X,
#    (...)
#     257     k=k,
#     258 )
#
# File c:\Users\Fabian\anaconda3\envs\group-23-env\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Fabian\anaconda3\envs\group-23-env\Lib\site-packages\sklearn\tree\_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File c:\Users\Fabian\anaconda3\envs\group-23-env\Lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
results_empty = pd.DataFrame(columns=['Time', 'Train', 'Test', 'f1'], index=[
                             'SMOTE', 'B-SMOTE', 'ADASYN'])

results_over = show_results(results_empty,
                       SMOTE(random_state=69),
                       BorderlineSMOTE(random_state=69),
                       ADASYN(random_state=69))

results_over
# Out:
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]
#                   Time        Train          Test                   f1
# SMOTE    52.505+/-3.04  0.754+/-0.0  0.729+/-0.01  0.236388+/-0.009103
# B-SMOTE  56.468+/-4.54  0.759+/-0.0   0.728+/-0.0  0.243142+/-0.009321
# ADASYN   53.848+/-2.01  0.751+/-0.0  0.732+/-0.01  0.232769+/-0.009269

# %%
results_empty = pd.DataFrame(columns=['Time', 'Train', 'Test', 'f1'], index=['SMOTEENN', 'SMOTETomek'])

results_comb = show_results(results_empty,
                       SMOTEENN(random_state=69, n_jobs=4),
                       SMOTETomek(random_state=69, n_jobs=4))

results_comb
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s finished
#                     Time        Train          Test                   f1
# SMOTEENN    2.217+/-0.21  0.781+/-0.0   0.508+/-0.0  0.231324+/-0.005761
# SMOTETomek  2.741+/-1.44  0.723+/-0.0  0.659+/-0.01  0.220391+/-0.009603

# %%
results_empty = pd.DataFrame(columns=['Time', 'Train', 'Test', 'f1'], index=[
                             'ENN03', 'ENN05', 'ENN07'])

results_enn = show_results(results_empty,
                       EditedNearestNeighbours(n_neighbors=3, kind_sel='all', n_jobs=4),
                       EditedNearestNeighbours(n_neighbors=5, kind_sel='all', n_jobs=4),
                       EditedNearestNeighbours(n_neighbors=7, kind_sel='all', n_jobs=4))

results_enn
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
#                Time        Train         Test                   f1
# ENN03  0.541+/-0.02  0.856+/-0.0   0.88+/-0.0  0.127599+/-0.015625
# ENN05  0.429+/-0.01  0.835+/-0.0  0.867+/-0.0  0.186579+/-0.018787
# ENN07   0.34+/-0.01  0.814+/-0.0  0.846+/-0.0  0.224199+/-0.011278

# %%
results_empty = pd.DataFrame(columns=['Time', 'Train', 'Test', 'f1'], index=[
                             'ENNmaj', 'ENNnotmaj', 'ENN'])

results_enn = show_results(results_empty,
                       EditedNearestNeighbours(n_neighbors=5, sampling_strategy='majority' ,kind_sel='all', n_jobs=4),
                       EditedNearestNeighbours(n_neighbors=5, sampling_strategy='not majority',kind_sel='all', n_jobs=4),
                       EditedNearestNeighbours(n_neighbors=7, kind_sel='all', n_jobs=4))

results_enn
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
#                    Time        Train         Test                   f1
# ENNmaj     0.435+/-0.02  0.835+/-0.0  0.867+/-0.0  0.187795+/-0.014603
# ENNnotmaj   0.56+/-0.08    1.0+/-0.0  0.888+/-0.0            0.0+/-0.0
# ENN        0.343+/-0.01  0.814+/-0.0  0.846+/-0.0    0.22323+/-0.01518

# %% [markdown]
# ENN 07 the best option
# would be nice to see how smotenk performs when we reduce the features

# %%
balancer = EditedNearestNeighbours(n_neighbors=7, kind_sel='all', n_jobs=4)
X_balanced, y_balanced = balancer.fit_resample(X_train, y.loc[X_train.index])

X_balanced.shape
# Out:
# (31151, 93)

# %% [markdown]
# <span style="color: red">TEST 1:</span> just with random oversampler

# %%
balancer = RandomOverSampler(random_state=69)
X_balanced, y_balanced = balancer.fit_resample(X_train, y.loc[X_train.index])

X_balanced.shape
# Out:
# (101256, 67)

# %%
rows = balancer.sample_indices_
og_indices = X_train.iloc[rows].index

X_balanced.set_index(og_indices, inplace=True)

X_balanced.head()
# Out:
#                 race_0    race_1    race_2    race_3  gender     age_0  \
# encounter_id
# 672135       -0.632456  0.534522 -0.316228  0.119523     1.0 -0.495434
# 181753       -0.632456  0.534522 -0.316228  0.119523     0.0 -0.385337
# 890706       -0.632456  0.534522 -0.316228  0.119523     0.0 -0.275241
# 648403       -0.632456  0.534522 -0.316228  0.119523     0.0 -0.055048
# 947413       -0.316228 -0.267261  0.632456 -0.478091     1.0 -0.055048
#
#                  age_1     age_2     age_3     age_4  ...  med_acetohexamide  \
# encounter_id                                          ...
# 672135        0.522233 -0.453425  0.336581 -0.214834  ...                  0
# 181753        0.174078  0.151142 -0.411377  0.501280  ...                  0
# 890706       -0.087039  0.377854 -0.317882 -0.035806  ...                  0
# 648403       -0.348155  0.129550  0.336581 -0.214834  ...                  0
# 947413       -0.348155  0.129550  0.336581 -0.214834  ...                  0
#
#               med_metformin-rosiglitazone  med_metformin  med_troglitazone  \
# encounter_id
# 672135                                  0              0                 0
# 181753                                  0              0                 0
# 890706                                  0              0                 0
# 648403                                  0              0                 0
# 947413                                  0              0                 0
#
#               med_miglitol  med_glipizide  med_glimepiride-pioglitazone  \
# encounter_id
# 672135                   0              0                             0
# 181753                   0              1                             0
# 890706                   0              0                             0
# 648403                   0              0                             0
# 947413                   0              0                             0
#
#               med_repaglinide  med_glyburide-metformin  age_mean
# encounter_id
# 672135                      0                        0  1.823370
# 181753                      0                        0  0.547373
# 890706                      0                        0  1.185371
# 648403                      0                        0 -1.366623
# 947413                      0                        0 -1.366623
#
# [5 rows x 93 columns]

# %%
# this to compare if the rows that we have are still the same

pd.DataFrame.compare(X_balanced, X_train.iloc[rows])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # this to compare if the rows that we have are still the same
# ----> 3 pd.DataFrame.compare(X_balanced, X_train.iloc[rows])
#
# NameError: name 'rows' is not defined

# %%
y_balanced.set_index(og_indices, inplace=True)
pd.DataFrame.compare(y_balanced, y.iloc[rows])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
y_new = pd.concat([y_balanced, y.loc[X_val.index]], axis=0)

# %%
y_new[y_new.index.duplicated()].shape
# Out:
# (21, 1)

# %%
y_new.shape
# Out:
# (115504, 1)

# %%
X_balanced.to_csv("../data/input/train_balanced.csv")

# %%
y_balanced.to_csv("../data/input/y_train.csv")

# %%
X_val.tail()
# Out:
#                          race  gender      age payer_code  \
# encounter_id
# 181659              Caucasian    Male  [50-60)         HM
# 332892        AfricanAmerican  Female  [70-80)    Unknown
# 925848              Caucasian    Male  [60-70)    Unknown
# 869407              Caucasian  Female  [70-80)         MC
# 988159              Caucasian    Male  [80-90)         SP
#
#               outpatient_visits_in_previous_year  \
# encounter_id
# 181659                                         0
# 332892                                         0
# 925848                                         0
# 869407                                         0
# 988159                                         0
#
#               emergency_visits_in_previous_year  \
# encounter_id
# 181659                                        0
# 332892                                        0
# 925848                                        0
# 869407                                        0
# 988159                                        0
#
#               inpatient_visits_in_previous_year admission_type  \
# encounter_id
# 181659                                        0       Elective
# 332892                                        1      Emergency
# 925848                                        1      Emergency
# 869407                                        0      Emergency
# 988159                                        2      Emergency
#
#               average_pulse_bpm  \
# encounter_id
# 181659                       89
# 332892                      103
# 925848                      127
# 869407                       72
# 988159                      106
#
#                                           discharge_disposition  ...  \
# encounter_id                                                     ...
# 181659                                       Discharged to home  ...
# 332892        Discharged/transferred to home with home healt...  ...
# 925848        Discharged/transferred to another rehab fac in...  ...
# 869407                                       Discharged to home  ...
# 988159                               Hospice / medical facility  ...
#
#              med_glimepiride-pioglitazone  med_nateglinide  med_glipizide  \
# encounter_id
# 181659                                  0                0              0
# 332892                                  0                0              0
# 925848                                  0                0              0
# 869407                                  0                0              1
# 988159                                  0                0              0
#
#               med_insulin  med_metformin-pioglitazone  \
# encounter_id
# 181659                  1                           0
# 332892                  0                           0
# 925848                  1                           0
# 869407                  0                           0
# 988159                  1                           0
#
#               med_metformin-rosiglitazone med_chlorpropamide med_miglitol  \
# encounter_id
# 181659                                  0                  0            0
# 332892                                  0                  0            0
# 925848                                  0                  0            0
# 869407                                  0                  0            0
# 988159                                  0                  0            0
#
#              med_repaglinide med_tolbutamide
# encounter_id
# 181659                     0               0
# 332892                     0               0
# 925848                     0               0
# 869407                     0               0
# 988159                     0               0
#
# [5 rows x 67 columns]
